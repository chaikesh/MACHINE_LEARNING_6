# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedKFold
from sklearn.cross_validation import train_test_split, KFold, cross_val_score
from catboost import CatBoostClassifier
from sklearn.metrics import f1_score

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
# Out:
# /home/chaikesh/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#data preparation

df1 = pd.read_csv('Building_Ownership_Use.csv')
print df1.shape
df1.head()

print df1.isnull().sum()
df1['count_families']=df1['count_families'].fillna(1.0)
df1['has_secondary_use']=df1['has_secondary_use'].fillna(0.0)


df2 = pd.read_csv('Building_Structure.csv')
df2.head()

df2['count_floors_diff']=df2['count_floors_pre_eq']-df2['count_floors_post_eq']
df2['height_ft_diff']=df2['height_ft_pre_eq']-df2['height_ft_post_eq']
df2['height_ft_diff']=df2['height_ft_diff'].clip_lower(0)
df2['count_floors_diff']=df2['count_floors_diff'].clip_lower(0)


df2['position']=df2['position'].fillna('Not attached')
df2['plan_configuration']=df2['plan_configuration'].fillna('Rectangular')

df2.drop(['count_floors_pre_eq','count_floors_post_eq','height_ft_pre_eq', 'height_ft_post_eq'],inplace=True,axis=1)
df2.head()

df3 = pd.read_csv('train.csv')

df3.head(5)

df4 = pd.read_csv('test.csv')

df4.head(5)


combined = pd.merge(df1,df2, on='building_id')

train_data=pd.merge(df3,combined,on="building_id")

test_data=pd.merge(df4,combined,on="building_id")
# Out:
# (1052948, 17)
# building_id                       0
# district_id                       0
# vdcmun_id                         0
# ward_id                           0
# legal_ownership_status            0
# count_families                    2
# has_secondary_use                10
# has_secondary_use_agriculture     0
# has_secondary_use_hotel           0
# has_secondary_use_rental          0
# has_secondary_use_institution     0
# has_secondary_use_school          0
# has_secondary_use_industry        0
# has_secondary_use_health_post     0
# has_secondary_use_gov_office      0
# has_secondary_use_use_police      0
# has_secondary_use_other           0
# dtype: int64

# %%
#preprocessing
df1=train_data
df1['has_repair_started']=df1['has_repair_started'].fillna(0)
df1['has_geotechnical_risk_sum']=df1['has_geotechnical_risk_fault_crack']+df1['has_geotechnical_risk_flood']+df1['has_geotechnical_risk_land_settlement']+df1['has_geotechnical_risk_landslide']+df1['has_geotechnical_risk_liquefaction']+df1['has_geotechnical_risk_other']+df1['has_geotechnical_risk_rock_fall']
df1.drop(columns = ['has_geotechnical_risk', 
       'has_geotechnical_risk_fault_crack',
       'has_geotechnical_risk_flood',
       'has_geotechnical_risk_land_settlement',
       'has_geotechnical_risk_landslide',
       'has_geotechnical_risk_liquefaction', 
       'has_geotechnical_risk_other',
       'has_geotechnical_risk_rock_fall',
       'has_secondary_use_agriculture', 
       'has_secondary_use_hotel',
       'has_secondary_use_rental', 
       'has_secondary_use_institution',
       'has_secondary_use_school',
       'has_secondary_use_industry',
       'has_secondary_use_health_post', 
       'has_secondary_use_gov_office',
       'has_secondary_use_use_police', 
       'has_secondary_use_other',
       'has_superstructure_adobe_mud',
       'has_superstructure_mud_mortar_stone',
       'has_superstructure_stone_flag',
       'has_superstructure_cement_mortar_stone',
       'has_superstructure_mud_mortar_brick',
       'has_superstructure_cement_mortar_brick', 
       'has_superstructure_timber',
       'has_superstructure_bamboo',
       'has_superstructure_rc_non_engineered',
       'has_superstructure_rc_engineered', 
       'has_superstructure_other'],inplace=True)

df_n=df1[['building_id','damage_grade']]
df1[['district_id','vdcmun_id','ward_id_x']]=df1[['district_id','vdcmun_id','ward_id_x']].astype(str)
df1.drop(columns=['building_id','damage_grade','district_id_x','district_id_y','vdcmun_id_x','vdcmun_id_y','ward_id_y'],inplace=True)

ptrain=pd.concat([df_n,df1],axis=1)


df2=test_data

df2['has_repair_started']=df2['has_repair_started'].fillna(0)
df_n=df2[['building_id']]
df2['has_geotechnical_risk_sum']=df2['has_geotechnical_risk_fault_crack']+df2['has_geotechnical_risk_flood']+df2['has_geotechnical_risk_land_settlement']+df2['has_geotechnical_risk_landslide']+df2['has_geotechnical_risk_liquefaction']+df2['has_geotechnical_risk_other']+df2['has_geotechnical_risk_rock_fall']
df2.drop(columns = ['has_geotechnical_risk', 
       'has_geotechnical_risk_fault_crack',
       'has_geotechnical_risk_flood',
       'has_geotechnical_risk_land_settlement',
       'has_geotechnical_risk_landslide',
       'has_geotechnical_risk_liquefaction', 
       'has_geotechnical_risk_other',
       'has_geotechnical_risk_rock_fall',
       'has_secondary_use_agriculture', 
       'has_secondary_use_hotel',
       'has_secondary_use_rental', 
       'has_secondary_use_institution',
       'has_secondary_use_school',
       'has_secondary_use_industry',
       'has_secondary_use_health_post', 
       'has_secondary_use_gov_office',
       'has_secondary_use_use_police', 
       'has_secondary_use_other',
       'has_superstructure_adobe_mud',
       'has_superstructure_mud_mortar_stone',
       'has_superstructure_stone_flag',
       'has_superstructure_cement_mortar_stone',
       'has_superstructure_mud_mortar_brick',
       'has_superstructure_cement_mortar_brick', 
       'has_superstructure_timber',
       'has_superstructure_bamboo',
       'has_superstructure_rc_non_engineered',
       'has_superstructure_rc_engineered', 
       'has_superstructure_other'],inplace=True)

df2[['district_id','vdcmun_id','ward_id_x']]=df2[['district_id','vdcmun_id','ward_id_x']].astype(str)
df2.drop(columns=['building_id','district_id_x','district_id_y','vdcmun_id_x','vdcmun_id_y','ward_id_y'],inplace=True)
ptest=pd.concat([df_n,df2],axis=1)

# %%
train=ptrain


train['damage_grade']=train['damage_grade'].str.replace('Grade ','')
train['damage_grade']=train['damage_grade'].str.replace('5','0').astype(float)

Y=train['damage_grade']

X=train.drop(['damage_grade','building_id'],axis=1)

X[['district_id','vdcmun_id','ward_id_x']]=X[['district_id','vdcmun_id','ward_id_x']].astype(str)





categorical_features_indices = np.where(X.dtypes==object)[0]
print categorical_features_indices
len(categorical_features_indices)
# Out:
# [ 0  1  3  4  5 10 11 12 13 14 15 16 17]
# 13

# %%
stack=pd.DataFrame()
stack["building_id"]=train.building_id
stack["target"]=Y


l=['0_cb','1_cb','2_cb','3_cb','4_cb']

for i in l:
    stack[i]=0

# %%
#fitting model
model = CatBoostClassifier(iterations=30,depth=8, learning_rate=0.5,loss_function='MultiClassOneVsAll',classes_count=5)
model.fit(X,Y,cat_features=categorical_features_indices,plot=False,verbose=True)

# %%
Y_ = model.predict(X)
stack[l]=model.predict_proba(X)
stack['cb']=Y_
score=f1_score(Y,Y_,average='weighted')

# %%
score
# Out:
# 0.8087300053770577

# %%
imp = model.get_feature_importance()
dic = X.columns
print len(imp),len(dic)

df = pd.DataFrame()
df['feature']=dic
df['importance']=imp
df.sort_values(by='importance',ascending=False)
# Out:
# 21 21
#                       feature  importance
# 17          condition_post_eq   27.120198
# 19             height_ft_diff   19.288840
# 4                   ward_id_x   15.548676
# 3                   vdcmun_id    8.192835
# 8                age_building    6.378681
# 0                area_assesed    6.084757
# 2          has_repair_started    4.158398
# 1                 district_id    3.202187
# 6              count_families    3.190809
# 11            foundation_type    2.210539
# 20  has_geotechnical_risk_sum    1.345003
# 12                  roof_type    1.161320
# 14           other_floor_type    0.760659
# 13          ground_floor_type    0.752728
# 9           plinth_area_sq_ft    0.445794
# 15                   position    0.158573
# 16         plan_configuration    0.000000
# 7           has_secondary_use    0.000000
# 18          count_floors_diff    0.000000
# 5      legal_ownership_status    0.000000
# 10     land_surface_condition    0.000000

# %%
stack_234=stack[stack['target']>=2]
stack_234.shape


score=f1_score(stack_234['target'].values,stack_234['cb'].values,average='weighted',labels=[2,3,4])
print score
# Out:
# 0.703167804038465

# %% [markdown]
# # model on top

# %%
l_1=['0_cb_1','1_cb_1','2_cb_1','3_cb_1','4_cb_1']

for i in l_1:
    stack[i]=0

# %%
#fitting model

X=train[train['damage_grade']>=2]
Y=X['damage_grade']-2
X=X.drop(['damage_grade','building_id'],axis=1)

X[['district_id','vdcmun_id','ward_id_x']]=X[['district_id','vdcmun_id','ward_id_x']].astype(str)


model_1 = CatBoostClassifier(iterations=150,depth=8, learning_rate=0.6,loss_function='MultiClass',classes_count=3)
model_1.fit(X,Y,cat_features=categorical_features_indices,plot=False,verbose=True)
# Out:
# 0:	learn: -0.9088339	total: 2.89s	remaining: 7m 11s
# 1:	learn: -0.8519402	total: 5.69s	remaining: 7m 1s
# 2:	learn: -0.8031821	total: 7.72s	remaining: 6m 18s
# 3:	learn: -0.7833708	total: 10.4s	remaining: 6m 20s
# 4:	learn: -0.7711471	total: 13.5s	remaining: 6m 31s
# 5:	learn: -0.7641692	total: 16.8s	remaining: 6m 42s
# 6:	learn: -0.7587333	total: 19.9s	remaining: 6m 45s
# 7:	learn: -0.7529756	total: 22.7s	remaining: 6m 42s
# 8:	learn: -0.7478828	total: 26s	remaining: 6m 47s
# 9:	learn: -0.7447530	total: 29.9s	remaining: 6m 58s
# 10:	learn: -0.7413014	total: 32.6s	remaining: 6m 52s
# 11:	learn: -0.7389965	total: 35.9s	remaining: 6m 52s
# 12:	learn: -0.7372846	total: 39.5s	remaining: 6m 56s
# 13:	learn: -0.7340848	total: 42.9s	remaining: 6m 57s
# 14:	learn: -0.7325419	total: 45.9s	remaining: 6m 53s
# 15:	learn: -0.7310151	total: 49.1s	remaining: 6m 50s
# 16:	learn: -0.7288148	total: 52.3s	remaining: 6m 49s
# 17:	learn: -0.7276080	total: 55.8s	remaining: 6m 48s
# 18:	learn: -0.7262278	total: 59.6s	remaining: 6m 50s
# 19:	learn: -0.7245269	total: 1m 2s	remaining: 6m 49s
# 20:	learn: -0.7231864	total: 1m 6s	remaining: 6m 48s
# 21:	learn: -0.7222385	total: 1m 10s	remaining: 6m 48s
# 22:	learn: -0.7213714	total: 1m 12s	remaining: 6m 42s
# 23:	learn: -0.7206481	total: 1m 16s	remaining: 6m 41s
# 24:	learn: -0.7193478	total: 1m 20s	remaining: 6m 41s
# 25:	learn: -0.7180785	total: 1m 23s	remaining: 6m 38s
# 26:	learn: -0.7170049	total: 1m 26s	remaining: 6m 34s
# 27:	learn: -0.7162195	total: 1m 30s	remaining: 6m 32s
# 28:	learn: -0.7148438	total: 1m 32s	remaining: 6m 27s
# 29:	learn: -0.7138483	total: 1m 35s	remaining: 6m 23s
# 30:	learn: -0.7131877	total: 1m 39s	remaining: 6m 20s
# 31:	learn: -0.7122752	total: 1m 42s	remaining: 6m 18s
# 32:	learn: -0.7118101	total: 1m 45s	remaining: 6m 15s
# 33:	learn: -0.7113766	total: 1m 49s	remaining: 6m 15s
# 34:	learn: -0.7105837	total: 1m 53s	remaining: 6m 11s
# 35:	learn: -0.7099517	total: 1m 56s	remaining: 6m 9s
# 36:	learn: -0.7093316	total: 1m 59s	remaining: 6m 5s
# 37:	learn: -0.7089731	total: 2m 3s	remaining: 6m 5s
# 38:	learn: -0.7084017	total: 2m 7s	remaining: 6m 2s
# 39:	learn: -0.7078889	total: 2m 10s	remaining: 5m 59s
# 40:	learn: -0.7074625	total: 2m 14s	remaining: 5m 57s
# 41:	learn: -0.7067437	total: 2m 17s	remaining: 5m 54s
# 42:	learn: -0.7064493	total: 2m 21s	remaining: 5m 51s
# 43:	learn: -0.7062864	total: 2m 25s	remaining: 5m 49s
# 44:	learn: -0.7057408	total: 2m 29s	remaining: 5m 48s
# 45:	learn: -0.7053827	total: 2m 33s	remaining: 5m 46s
# 46:	learn: -0.7045924	total: 2m 37s	remaining: 5m 45s
# 47:	learn: -0.7040091	total: 2m 41s	remaining: 5m 43s
# 48:	learn: -0.7038154	total: 2m 45s	remaining: 5m 40s
# 49:	learn: -0.7034249	total: 2m 48s	remaining: 5m 37s
# 50:	learn: -0.7029278	total: 2m 52s	remaining: 5m 34s
# 51:	learn: -0.7023433	total: 2m 55s	remaining: 5m 30s
# 52:	learn: -0.7022079	total: 2m 59s	remaining: 5m 28s
# 53:	learn: -0.7018247	total: 3m 3s	remaining: 5m 25s
# 54:	learn: -0.7011587	total: 3m 6s	remaining: 5m 21s
# 55:	learn: -0.7005480	total: 3m 10s	remaining: 5m 19s
# 56:	learn: -0.7001585	total: 3m 14s	remaining: 5m 16s
# 57:	learn: -0.7000445	total: 3m 17s	remaining: 5m 13s
# 58:	learn: -0.6996031	total: 3m 21s	remaining: 5m 10s
# 59:	learn: -0.6991173	total: 3m 25s	remaining: 5m 7s
# 60:	learn: -0.6990125	total: 3m 29s	remaining: 5m 5s
# 61:	learn: -0.6986960	total: 3m 33s	remaining: 5m 2s
# 62:	learn: -0.6986253	total: 3m 37s	remaining: 4m 59s
# 63:	learn: -0.6983773	total: 3m 40s	remaining: 4m 56s
# 64:	learn: -0.6980296	total: 3m 44s	remaining: 4m 53s
# 65:	learn: -0.6978260	total: 3m 47s	remaining: 4m 49s
# 66:	learn: -0.6974863	total: 3m 51s	remaining: 4m 46s
# 67:	learn: -0.6972854	total: 3m 55s	remaining: 4m 43s
# 68:	learn: -0.6970142	total: 3m 58s	remaining: 4m 39s
# 69:	learn: -0.6965004	total: 4m 1s	remaining: 4m 36s
# 70:	learn: -0.6962639	total: 4m 5s	remaining: 4m 32s
# 71:	learn: -0.6958460	total: 4m 8s	remaining: 4m 29s
# 72:	learn: -0.6954250	total: 4m 12s	remaining: 4m 26s
# 73:	learn: -0.6950265	total: 4m 16s	remaining: 4m 23s
# 74:	learn: -0.6947163	total: 4m 19s	remaining: 4m 19s
# 75:	learn: -0.6944024	total: 4m 23s	remaining: 4m 16s
# 76:	learn: -0.6939085	total: 4m 26s	remaining: 4m 12s
# 77:	learn: -0.6937631	total: 4m 30s	remaining: 4m 9s
# 78:	learn: -0.6935881	total: 4m 33s	remaining: 4m 6s
# 79:	learn: -0.6932733	total: 4m 37s	remaining: 4m 3s
# 80:	learn: -0.6931974	total: 4m 41s	remaining: 3m 59s
# 81:	learn: -0.6928775	total: 4m 44s	remaining: 3m 56s
# 82:	learn: -0.6925783	total: 4m 48s	remaining: 3m 53s
# 83:	learn: -0.6924784	total: 4m 52s	remaining: 3m 49s
# 84:	learn: -0.6920815	total: 4m 55s	remaining: 3m 46s
# 85:	learn: -0.6919806	total: 4m 59s	remaining: 3m 42s
# 86:	learn: -0.6918950	total: 5m 3s	remaining: 3m 39s
# 87:	learn: -0.6916579	total: 5m 6s	remaining: 3m 36s
# 88:	learn: -0.6912289	total: 5m 10s	remaining: 3m 32s
# 89:	learn: -0.6910910	total: 5m 14s	remaining: 3m 29s
# 90:	learn: -0.6909921	total: 5m 17s	remaining: 3m 26s
# 91:	learn: -0.6908742	total: 5m 21s	remaining: 3m 22s
# 92:	learn: -0.6905861	total: 5m 25s	remaining: 3m 19s
# 93:	learn: -0.6900540	total: 5m 29s	remaining: 3m 16s
# 94:	learn: -0.6899637	total: 5m 32s	remaining: 3m 12s
# 95:	learn: -0.6898613	total: 5m 36s	remaining: 3m 9s
# 96:	learn: -0.6897017	total: 5m 40s	remaining: 3m 5s
# 97:	learn: -0.6895007	total: 5m 43s	remaining: 3m 2s
# 98:	learn: -0.6893688	total: 5m 47s	remaining: 2m 58s
# 99:	learn: -0.6888100	total: 5m 50s	remaining: 2m 55s
# 100:	learn: -0.6886998	total: 5m 54s	remaining: 2m 52s
# 101:	learn: -0.6882742	total: 5m 58s	remaining: 2m 48s
# 102:	learn: -0.6877330	total: 6m 1s	remaining: 2m 45s
# 103:	learn: -0.6873639	total: 6m 5s	remaining: 2m 41s
# 104:	learn: -0.6872542	total: 6m 9s	remaining: 2m 38s
# 105:	learn: -0.6870734	total: 6m 12s	remaining: 2m 34s
# 106:	learn: -0.6866289	total: 6m 16s	remaining: 2m 31s
# 107:	learn: -0.6865098	total: 6m 20s	remaining: 2m 28s
# 108:	learn: -0.6862837	total: 6m 24s	remaining: 2m 24s
# 109:	learn: -0.6860135	total: 6m 28s	remaining: 2m 21s
# 110:	learn: -0.6858274	total: 6m 32s	remaining: 2m 18s
# 111:	learn: -0.6856086	total: 6m 36s	remaining: 2m 14s
# 112:	learn: -0.6852491	total: 6m 40s	remaining: 2m 11s
# 113:	learn: -0.6848684	total: 6m 44s	remaining: 2m 7s
# 114:	learn: -0.6847398	total: 6m 47s	remaining: 2m 4s
# 115:	learn: -0.6843152	total: 6m 51s	remaining: 2m
# 116:	learn: -0.6842196	total: 6m 54s	remaining: 1m 57s
# 117:	learn: -0.6838344	total: 6m 58s	remaining: 1m 53s
# 118:	learn: -0.6831826	total: 7m 2s	remaining: 1m 49s
# 119:	learn: -0.6830188	total: 7m 5s	remaining: 1m 46s
# 120:	learn: -0.6827022	total: 7m 9s	remaining: 1m 42s
# 121:	learn: -0.6824839	total: 7m 13s	remaining: 1m 39s
# 122:	learn: -0.6822998	total: 7m 16s	remaining: 1m 35s
# 123:	learn: -0.6817922	total: 7m 20s	remaining: 1m 32s
# 124:	learn: -0.6816457	total: 7m 22s	remaining: 1m 28s
# 125:	learn: -0.6812174	total: 7m 26s	remaining: 1m 25s
# 126:	learn: -0.6808794	total: 7m 30s	remaining: 1m 21s
# 127:	learn: -0.6807943	total: 7m 33s	remaining: 1m 17s
# 128:	learn: -0.6804298	total: 7m 36s	remaining: 1m 14s
# 129:	learn: -0.6802148	total: 7m 39s	remaining: 1m 10s
# 130:	learn: -0.6799036	total: 7m 43s	remaining: 1m 7s
# 131:	learn: -0.6797725	total: 7m 46s	remaining: 1m 3s
# 132:	learn: -0.6796982	total: 7m 50s	remaining: 1m
# 133:	learn: -0.6794854	total: 7m 53s	remaining: 56.5s
# 134:	learn: -0.6792392	total: 7m 56s	remaining: 52.9s
# 135:	learn: -0.6788024	total: 7m 59s	remaining: 49.4s
# 136:	learn: -0.6787115	total: 8m 3s	remaining: 45.9s
# 137:	learn: -0.6786525	total: 8m 6s	remaining: 42.3s
# 138:	learn: -0.6785613	total: 8m 10s	remaining: 38.8s
# 139:	learn: -0.6785177	total: 8m 13s	remaining: 35.3s
# 140:	learn: -0.6781986	total: 8m 17s	remaining: 31.8s
# 141:	learn: -0.6781211	total: 8m 20s	remaining: 28.2s
# 142:	learn: -0.6778338	total: 8m 24s	remaining: 24.7s
# 143:	learn: -0.6773528	total: 8m 27s	remaining: 21.2s
# 144:	learn: -0.6772938	total: 8m 31s	remaining: 17.6s
# 145:	learn: -0.6771158	total: 8m 34s	remaining: 14.1s
# 146:	learn: -0.6769869	total: 8m 37s	remaining: 10.6s
# 147:	learn: -0.6767632	total: 8m 42s	remaining: 7.05s
# 148:	learn: -0.6765367	total: 8m 45s	remaining: 3.53s
# 149:	learn: -0.6763593	total: 8m 49s	remaining: 0us

# %%
pred = model_1.predict(X)+2
Y1=Y+2

score=f1_score(Y1,pred,average='weighted',labels=[2,3,4])
score
# Out:
# 0.7178572876604519

# %%
filename = 'second_model.sav'
pickle.dump(model_1, open(filename, 'wb'))

# %% [markdown]
# # Final model

# %%
#test data 

test=ptest
print test.shape
b_id = test['building_id']
test_x=test.drop(['building_id'],axis=1)
# Out:
# (421175, 22)

# %%
#predicting on test-set

test_y = model.predict(test_x)

test_x['target']=test_y
test_x['b_id']=b_id
test_x.head()
# Out:
#        area_assesed district_id  has_repair_started vdcmun_id ward_id_x  \
# 0              Both           7                 1.0       701     70102
# 1              Both           7                 1.0       701     70103
# 2  Building removed           7                 1.0       701     70103
# 3              Both           7                 1.0       701     70106
# 4  Building removed           7                 1.0       701     70107
#
#   legal_ownership_status  count_families  has_secondary_use  age_building  \
# 0                Private             1.0                0.0            28
# 1                Private             1.0                0.0            25
# 2                Private             1.0                0.0            35
# 3                Private             1.0                0.0            22
# 4                Private             1.0                0.0            24
#
#    plinth_area_sq_ft land_surface_condition         foundation_type  \
# 0                454         Moderate slope  Mud mortar-Stone/Brick
# 1                542         Moderate slope  Mud mortar-Stone/Brick
# 2                589         Moderate slope  Mud mortar-Stone/Brick
# 3                468         Moderate slope  Mud mortar-Stone/Brick
# 4                426         Moderate slope  Mud mortar-Stone/Brick
#
#                   roof_type ground_floor_type   other_floor_type  \
# 0  Bamboo/Timber-Light roof               Mud     Not applicable
# 1  Bamboo/Timber-Light roof               Mud     Not applicable
# 2  Bamboo/Timber-Light roof               Mud  TImber/Bamboo-Mud
# 3  Bamboo/Timber-Light roof               Mud  TImber/Bamboo-Mud
# 4  Bamboo/Timber-Light roof               Mud     Not applicable
#
#           position plan_configuration  \
# 0  Attached-1 side        Rectangular
# 1  Attached-1 side        Rectangular
# 2  Attached-1 side        Rectangular
# 3  Attached-1 side        Rectangular
# 4  Attached-1 side        Rectangular
#
#                          condition_post_eq  count_floors_diff  height_ft_diff  \
# 0                Damaged-Repaired and used                  0               0
# 1                   Damaged-Rubble unclear                  1               9
# 2  Damaged-Rubble Clear-New building built                  2              18
# 3                Damaged-Repaired and used                  0               0
# 4  Damaged-Rubble Clear-New building built                  1               9
#
#    has_geotechnical_risk_sum  target        b_id
# 0                          0     3.0  a3380c4f75
# 1                          0     0.0  a338a4e653
# 2                          0     0.0  a338a4e6b7
# 3                          0     3.0  a33a6eaa3a
# 4                          0     0.0  a33b073ff6

# %%
test_234= test_x[test_x['target']>=2]
test_234.shape
# Out:
# (245959, 23)

# %%
test_234_x = test_234.drop(['b_id','target'],axis=1)
t_234 = model_1.predict(test_234_x)+2
test_234['target']=t_234
# Out:
# /home/chaikesh/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
test_x.update(test_234)

# %%
# writing into submission file

sample=pd.read_csv('sample_submission.csv')
print sample.head()
sample['damage_grade']=test_x['target']
print sample.head()
sample['damage_grade']=sample['damage_grade'].astype(int).astype(str).str.replace('0','5')
sample['damage_grade']='Grade '+sample['damage_grade']
sample.to_csv('submission.csv',index=False)
print sample.head()
# Out:
#   building_id damage_grade
# 0  a3380c4f75      Grade 3
# 1  a338a4e653      Grade 1
# 2  a338a4e6b7      Grade 1
# 3  a33a6eaa3a      Grade 5
# 4  a33b073ff6      Grade 4
#   building_id  damage_grade
# 0  a3380c4f75           3.0
# 1  a338a4e653           0.0
# 2  a338a4e6b7           0.0
# 3  a33a6eaa3a           3.0
# 4  a33b073ff6           0.0
#   building_id damage_grade
# 0  a3380c4f75      Grade 3
# 1  a338a4e653      Grade 5
# 2  a338a4e6b7      Grade 5
# 3  a33a6eaa3a      Grade 3
# 4  a33b073ff6      Grade 5
